# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv("../input/au-dom-traffic/audomcitypairs-201909.csv")

# %%
df.head()
# Out:
#       City1          City2  Month  Passenger_Trips  Aircraft_Trips  \
# 0  ADELAIDE  ALICE SPRINGS  30682            15743             143
# 1  ADELAIDE       BRISBANE  30682             3781              32
# 2  ADELAIDE       CANBERRA  30682             1339              12
# 3  ADELAIDE         DARWIN  30682             3050              33
# 4  ADELAIDE     GOLD COAST  30682             1596              16
#
#    Passenger_Load_Factor  Distance_GC_(km)      RPKs      ASKs  Seats  Year  \
# 0                   81.8              1316  20717788  25327369  19246  1984
# 1                   89.8              1622   6132782   6829379   4210  1984
# 2                   94.7               972   1301508   1374348   1414  1984
# 3                   66.8              2619   7987950  11958009   4566  1984
# 4                   88.5              1607   2564772   2898047   1803  1984
#
#    Month_num
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
passenger_load = []
for i in df['City1'].unique():
    passenger_load.append([i,df[df['City1']==i].groupby('City1')['Passenger_Load_Factor'].mean()[0]])
passenger_load = pd.DataFrame(passenger_load)
passenger_load.columns = ["City","PassengerLoadFactor"]

# %%
fig = go.Figure(data=[go.Bar(x=passenger_load['City'],y=passenger_load['PassengerLoadFactor'],hovertext=passenger_load['City'])],layout_title_text="Average Number oF Passenger Load Factor for City")
fig.show()
# px.bar(x='City',y='PassengerLoadFactor',data_frame=passenger_load)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="161bb1b7-8a98-4c13-9034-09943e00497c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("161bb1b7-8a98-4c13-9034-09943e00497c")) {
#                     Plotly.newPlot(
#                         '161bb1b7-8a98-4c13-9034-09943e00497c',
#                         [{"hovertext": ["ADELAIDE", "ALBURY", "ALICE SPRINGS", "BRISBANE", "BROOME", "CANBERRA", "COFFS HARBOUR", "DARWIN", "DEVONPORT", "DUBBO", "GOLD COAST", "HOBART", "KALGOORLIE", "KARRATHA", "LAUNCESTON", "MELBOURNE", "PERTH", "SUNSHINE COAST", "SYDNEY", "CAIRNS", "BALLINA", "HERVEY BAY", "PORT MACQUARIE", "NEWCASTLE", "HAMILTON ISLAND", "AYERS ROCK", "GERALDTON", "BUNDABERG", "ARMIDALE", "PROSERPINE"], "type": "bar", "x": ["ADELAIDE", "ALBURY", "ALICE SPRINGS", "BRISBANE", "BROOME", "CANBERRA", "COFFS HARBOUR", "DARWIN", "DEVONPORT", "DUBBO", "GOLD COAST", "HOBART", "KALGOORLIE", "KARRATHA", "LAUNCESTON", "MELBOURNE", "PERTH", "SUNSHINE COAST", "SYDNEY", "CAIRNS", "BALLINA", "HERVEY BAY", "PORT MACQUARIE", "NEWCASTLE", "HAMILTON ISLAND", "AYERS ROCK", "GERALDTON", "BUNDABERG", "ARMIDALE", "PROSERPINE"], "y": [71.30475218658894, 67.3416861826698, 48.27419354838717, 72.64258160237378, 75.15337995338001, 66.40116550116552, 71.91748251748247, 65.07960264900672, 48.458630136986294, 63.687195585687675, 80.96689976689974, 77.68292349726775, 63.56363636363632, 63.0114219114219, 76.61065573770495, 70.08046744574285, 68.1263014594451, 78.57490952955371, 71.74224537037036, 73.92795294370246, 74.50528052805282, 35.60366972477065, 71.55531914893618, 36.68648648648649, 63.24271356783917, 75.98181818181818, 53.60736842105264, 68.59102564102565, 64.31969696969695, 78.10000000000001]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
px.scatter(x='Passenger_Load_Factor',y='City1',data_frame=df,title="Load Factor of Each City")
# Out:
# <div>
#
#
#             <div id="f1902620-fa8d-452e-a639-d68cd4f7177e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1902620-fa8d-452e-a639-d68cd4f7177e")) {
#                     Plotly.newPlot(
#                         'f1902620-fa8d-452e-a639-d68cd4f7177e',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Passenger_Load_Factor=%{x}<br>City1=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [81.8, 89.8, 94.7, 66.8, 88.5, 66.3, 85.1, 80.8, 79.8, 71.2, 75.8, 71.9, 72.7, 80.7, 48.2, 84.4, 88.2, 76.1, 77.2, 73.7, 82.0, 72.5, 60.5, 56.4, 79.8, 56.4, 72.5, 64.1, 81.9, 76.1, 51.4, 75.5, 74.6, 64.7, 84.9, 42.3, 37.2, 82.7, 66.5, 85.0, 65.3, 88.4, 56.5, 78.4, 64.2, 73.7, 58.2, 66.7, 68.7, 81.5, 76.7, 68.2, 67.4, 67.9, 54.6, 38.7, 0.0, 71.3, 57.6, 59.7, 72.8, 70.1, 77.4, 69.3, 66.9, 61.5, 69.1, 52.0, 65.3, 72.5, 72.7, 65.1, 78.7, 72.3, 55.6, 78.8, 52.6, 25.9, 77.4, 73.2, 78.1, 54.9, 72.2, 56.0, 71.4, 62.3, 86.3, 53.5, 55.2, 70.2, 80.1, 75.2, 70.5, 67.5, 64.1, 48.9, 52.9, 48.8, 69.6, 64.9, 71.5, 77.9, 71.1, 80.2, 67.3, 75.5, 64.0, 63.8, 73.0, 52.4, 67.4, 72.5, 66.1, 59.0, 78.0, 72.7, 52.3, 71.7, 45.6, 44.0, 77.8, 72.3, 76.4, 63.2, 81.6, 61.5, 77.9, 72.8, 76.5, 57.8, 56.7, 71.7, 80.9, 76.4, 77.2, 71.1, 77.7, 79.0, 56.3, 77.4, 63.4, 80.1, 74.3, 80.6, 77.3, 74.8, 87.3, 58.3, 18.6, 66.3, 63.9, 72.9, 52.8, 57.1, 71.5, 72.4, 71.8, 59.4, 80.7, 70.9, 65.5, 73.8, 38.0, 79.3, 73.4, 78.4, 68.1, 95.1, 67.7, 77.2, 76.6, 86.5, 66.6, 70.0, 71.6, 79.4, 79.1, 76.9, 76.1, 74.2, 66.7, 56.6, 78.8, 46.8, 73.8, 76.0, 68.4, 76.2, 70.3, 80.1, 74.6, 75.5, 65.1, 66.3, 76.4, 51.3, 74.2, 66.8, 69.1, 59.5, 82.1, 67.0, 53.6, 73.9, 37.9, 76.9, 74.2, 77.5, 63.2, 76.0, 65.7, 73.6, 60.8, 77.3, 84.1, 52.6, 68.6, 79.7, 76.4, 72.1, 84.1, 69.5, 80.5, 37.2, 86.6, 64.0, 77.9, 54.6, 67.5, 79.6, 73.4, 86.7, 59.5, 61.3, 58.2, 62.1, 85.1, 47.0, 73.1, 71.8, 67.8, 58.3, 84.0, 67.1, 51.3, 81.6, 40.7, 75.7, 71.6, 75.9, 51.8, 81.6, 71.7, 80.4, 65.2, 77.3, 86.5, 57.8, 69.3, 74.5, 77.2, 79.1, 79.3, 79.9, 83.0, 37.6, 75.6, 54.2, 77.9, 65.5, 67.9, 75.7, 72.9, 86.9, 81.1, 63.0, 65.7, 74.7, 71.6, 49.9, 67.9, 70.1, 67.2, 62.2, 85.2, 69.7, 54.4, 83.1, 40.3, 73.9, 70.1, 74.4, 50.5, 86.9, 63.5, 83.7, 75.6, 87.8, 74.2, 68.1, 75.3, 77.7, 79.9, 84.8, 81.5, 80.2, 72.3, 54.9, 76.0, 66.0, 81.4, 76.9, 77.0, 76.7, 75.9, 84.3, 74.9, 66.2, 60.6, 66.2, 78.9, 76.3, 59.8, 73.9, 70.8, 70.9, 60.9, 79.8, 72.0, 63.2, 81.2, 37.5, 75.8, 73.1, 77.9, 61.0, 87.3, 65.9, 79.5, 74.3, 89.6, 69.2, 78.7, 71.1, 83.1, 78.5, 84.8, 82.1, 73.5, 74.7, 53.6, 83.6, 56.4, 82.2, 64.2, 81.5, 81.8, 74.5, 85.6, 82.6, 87.4, 62.5, 65.3, 70.0, 63.2, 68.0, 74.4, 69.3, 65.7, 78.4, 68.8, 67.4, 83.2, 43.5, 75.7, 71.9, 84.4, 66.5, 84.2, 65.3, 74.3, 69.8, 87.9, 65.4, 83.6, 73.6, 82.8, 78.0, 84.3, 73.4, 63.5, 72.7, 49.8, 89.9, 54.0, 78.7, 62.2, 76.9, 80.1, 71.9, 81.0, 82.4, 100.7, 64.1, 65.9, 76.8, 49.0, 52.8, 80.2, 78.9, 74.5, 67.6, 75.7, 71.0, 59.2, 87.8, 38.8, 74.3, 71.7, 83.3, 67.1, 80.1, 65.7, 76.4, 62.2, 86.5, 77.0, 61.3, 73.0, 85.3, 78.4, 78.7, 69.1, 67.6, 40.6, 37.9, 66.0, 83.8, 78.2, 56.4, 68.0, 67.8, 72.0, 82.2, 82.1, 74.8, 70.0, 63.5, 76.8, 58.1, 75.9, 76.5, 76.4, 63.9, 73.2, 69.2, 66.2, 87.8, 42.9, 80.2, 73.5, 78.8, 57.9, 73.4, 64.1, 74.7, 87.6, 75.7, 77.9, 74.8, 68.7, 85.9, 79.7, 81.4, 64.9, 73.7, 70.6, 45.8, 75.1, 71.0, 78.9, 81.3, 70.3, 77.5, 75.7, 84.1, 70.5, 75.8, 63.5, 60.2, 74.6, 82.7, 72.7, 73.3, 73.3, 73.2, 63.4, 56.0, 72.3, 72.6, 79.4, 37.5, 82.0, 72.6, 87.0, 73.1, 83.0, 61.4, 75.8, 99.2, 85.0, 77.3, 77.2, 66.3, 87.3, 79.8, 83.9, 60.2, 69.1, 64.7, 64.2, 77.1, 74.2, 80.3, 99.7, 80.8, 76.2, 72.3, 85.4, 72.9, 66.3, 62.4, 57.0, 71.1, 55.8, 86.8, 61.1, 82.8, 78.6, 51.9, 65.0, 76.2, 76.4, 88.1, 37.2, 84.0, 70.4, 87.4, 79.7, 86.5, 51.6, 69.1, 54.5, 52.9, 66.5, 42.8, 70.5, 86.6, 66.1, 81.8, 69.7, 57.4, 31.5, 41.6, 48.7, 0.0, 66.3, 49.5, 28.1, 70.5, 54.0, 77.7, 76.6, 62.6, 60.3, 75.8, 83.7, 76.2, 68.9, 57.2, 65.7, 57.7, 77.3, 86.1, 75.2, 37.7, 84.4, 72.7, 84.4, 58.6, 86.3, 61.9, 71.7, 56.5, 64.5, 50.9, 55.7, 71.8, 87.2, 66.1, 86.3, 69.3, 64.1, 74.5, 37.0, 68.8, 59.1, 59.4, 70.3, 40.7, 75.4, 64.8, 81.3, 66.8, 66.5, 68.7, 65.4, 69.4, 85.5, 72.6, 66.8, 68.7, ...

# %%
px.scatter(x='Aircraft_Trips',y='City1',data_frame=df)
# Out:
# <div>
#
#
#             <div id="41412ff9-5126-4f36-a74b-89d75e6f1a16" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("41412ff9-5126-4f36-a74b-89d75e6f1a16")) {
#                     Plotly.newPlot(
#                         '41412ff9-5126-4f36-a74b-89d75e6f1a16',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Aircraft_Trips=%{x}<br>City1=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [143, 32, 12, 33, 16, 711, 144, 358, 296, 89, 31, 31, 8, 22, 15, 324, 4, 92, 287, 990, 376, 12, 323, 562, 166, 9, 380, 136, 454, 440, 110, 148, 647, 342, 159, 126, 16, 295, 1368, 163, 144, 50, 139, 91, 31, 12, 8, 12, 598, 121, 298, 276, 66, 26, 19, 2, 1, 222, 4, 66, 256, 871, 326, 17, 334, 583, 143, 233, 129, 351, 321, 112, 127, 533, 248, 46, 131, 12, 249, 1311, 114, 98, 17, 149, 118, 38, 13, 19, 19, 677, 129, 368, 294, 71, 29, 32, 10, 6, 281, 5, 73, 278, 943, 367, 7, 1, 390, 650, 133, 242, 124, 369, 379, 232, 153, 581, 266, 68, 253, 2, 265, 1461, 122, 98, 13, 148, 123, 36, 14, 16, 15, 633, 134, 358, 243, 73, 25, 61, 7, 13, 22, 292, 5, 81, 277, 943, 366, 10, 1, 358, 575, 164, 1, 292, 134, 426, 401, 229, 139, 592, 266, 148, 242, 222, 1355, 128, 111, 18, 143, 135, 34, 13, 32, 14, 714, 140, 380, 245, 82, 29, 34, 8, 6, 12, 345, 4, 89, 288, 1010, 411, 9, 3, 406, 648, 145, 272, 141, 436, 385, 245, 179, 611, 271, 150, 312, 259, 1494, 150, 104, 76, 149, 124, 38, 10, 27, 18, 648, 126, 317, 246, 75, 31, 32, 7, 15, 9, 261, 5, 84, 267, 931, 402, 9, 2, 380, 577, 144, 211, 154, 306, 322, 234, 137, 494, 234, 86, 296, 194, 1353, 100, 87, 59, 137, 131, 40, 14, 38, 16, 671, 133, 354, 184, 84, 31, 30, 6, 25, 15, 300, 4, 92, 296, 1007, 420, 6, 388, 618, 150, 1, 184, 145, 333, 312, 218, 154, 484, 214, 107, 317, 227, 1436, 109, 84, 91, 157, 135, 39, 13, 36, 16, 719, 145, 377, 193, 86, 35, 36, 6, 24, 7, 384, 4, 90, 303, 1028, 406, 15, 2, 407, 637, 142, 1, 185, 136, 416, 331, 245, 166, 565, 230, 227, 312, 252, 1492, 133, 87, 92, 138, 125, 39, 12, 25, 20, 657, 136, 378, 191, 77, 31, 57, 8, 12, 10, 361, 5, 89, 310, 1001, 397, 12, 2, 381, 606, 166, 212, 162, 441, 387, 226, 167, 604, 232, 167, 286, 277, 1430, 132, 105, 93, 163, 129, 39, 14, 17, 16, 698, 142, 367, 185, 78, 30, 17, 9, 4, 9, 331, 4, 90, 290, 994, 401, 8, 1, 402, 641, 157, 2, 184, 154, 389, 338, 245, 151, 610, 220, 136, 354, 263, 1534, 123, 89, 78, 168, 114, 34, 17, 13, 16, 693, 129, 338, 189, 69, 29, 11, 8, 12, 58, 326, 4, 85, 289, 983, 387, 4, 2, 392, 753, 148, 193, 147, 396, 321, 238, 148, 533, 171, 85, 335, 227, 1529, 122, 107, 37, 162, 106, 35, 15, 37, 16, 621, 133, 355, 192, 67, 23, 37, 5, 36, 37, 348, 6, 92, 278, 955, 370, 9, 4, 324, 666, 169, 10, 279, 138, 456, 343, 206, 223, 555, 251, 132, 295, 214, 1309, 121, 126, 55, 151, 126, 31, 16, 42, 17, 656, 138, 358, 191, 92, 30, 7, 4, 41, 14, 385, 4, 84, 280, 933, 366, 8, 1, 321, 697, 181, 12, 320, 162, 517, 442, 220, 222, 602, 289, 165, 275, 262, 1314, 165, 141, 59, 161, 110, 33, 19, 10, 18, 629, 116, 296, 173, 66, 26, 8, 6, 8, 9, 229, 4, 85, 242, 917, 345, 8, 369, 701, 139, 198, 135, 369, 320, 210, 197, 552, 187, 76, 315, 215, 1412, 118, 106, 16, 147, 124, 38, 23, 14, 18, 694, 146, 393, 194, 76, 32, 12, 12, 8, 16, 373, 5, 78, 282, 971, 383, 6, 2, 406, 803, 182, 247, 157, 423, 318, 243, 211, 670, 203, 95, 306, 231, 1547, 123, 18, 123, 25, 167, 123, 29, 19, 19, 10, 656, 134, 376, 192, 76, 26, 36, 9, 17, 22, 303, 3, 58, 272, 927, 371, 12, 1, 372, 745, 199, 1, 276, 156, 429, 370, 228, 228, 612, 220, 108, 315, 219, 1426, 112, 22, 120, 29, 161, 125, 33, 22, 20, 13, 720, 140, 377, 214, 93, 42, 35, 10, 16, 27, 388, 5, 89, 304, 1037, 395, 14, 3, 427, 807, 213, 249, 167, 480, 363, 243, 246, 632, 205, 161, 364, 258, 1619, 130, 26, 126, 75, 180, 123, 33, 20, 18, 15, 651, 127, 350, 218, 94, 40, 37, 4, 22, 31, 310, 5, 75, 290, 948, 377, 9, 5, 371, 714, 170, 340, 154, 404, 333, 220, 219, 491, 252, 93, 312, 213, 1451, 104, 22, 117, 73, 159, 129, 41, 35, 24, 17, 701, 133, 310, 192, 110, 44, 37, 39, 30, 60, 355, 4, 78, 305, 862, 431, 6, 3, 440, 654, 160, 3, 282, 149, 362, 287, 240, 249, 534, 217, 108, 331, 14, 242, 1376, 89, 25, 107, 62, 149, 134, 45, 28, 29, 20, 715, 141, 375, 271, 118, 59, 36, 7, ...

# %%
_20191 = df[(df['Year']==2019)&(df['Month_num']==1)]
_20191.head()
# Out:
#           City1          City2  Month  Passenger_Trips  Aircraft_Trips  \
# 19143    ALBURY         SYDNEY  43466            15654             384
# 19198  ADELAIDE  ALICE SPRINGS  43466            10281             115
# 19261  ADELAIDE       BRISBANE  43466            71227             585
# 19324  ADELAIDE       CANBERRA  43466            11865             122
# 19387  ADELAIDE      MELBOURNE  43466           199040            1546
#
#        Passenger_Load_Factor  Distance_GC_(km)       RPKs       ASKs   Seats  \
# 19143                   68.3               452    7075608   10365716   22933
# 19198                   66.6              1316   13529796   20329568   15448
# 19261                   75.3              1622  115530194  153470396   94618
# 19324                   58.6               972   11532780   19669392   20236
# 19387                   77.7               643  127925990  164741715  256305
#
#        Year  Month_num
# 19143  2019          1
# 19198  2019          1
# 19261  2019          1
# 19324  2019          1
# 19387  2019          1

# %%
average_seats = _20191.groupby('City1')['Seats'].mean()
px.bar(data_frame=df,x=average_seats.index,y=average_seats.values)
# Out:
# <div>
#
#
#             <div id="445c7220-da89-4f93-900c-a397bf932d23" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("445c7220-da89-4f93-900c-a397bf932d23")) {
#                     Plotly.newPlot(
#                         '445c7220-da89-4f93-900c-a397bf932d23',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["ADELAIDE", "ALBURY", "ALICE SPRINGS", "ARMIDALE", "AYERS ROCK", "BALLINA", "BRISBANE", "BROOME", "BUNDABERG", "CAIRNS", "CANBERRA", "COFFS HARBOUR", "DARWIN", "DUBBO", "GERALDTON", "GOLD COAST", "HAMILTON ISLAND", "HOBART", "KALGOORLIE", "KARRATHA", "LAUNCESTON", "MELBOURNE", "PERTH", "PORT MACQUARIE", "PROSERPINE", "SUNSHINE COAST", "SYDNEY"], "xaxis": "x", "y": [87479.125, 22933.0, 3814.3333333333335, 12874.0, 20608.0, 53450.0, 94006.94117647059, 33288.0, 17992.0, 77514.0, 96447.0, 37994.0, 28253.666666666668, 18076.0, 16400.0, 289050.0, 15093.5, 148861.5, 38290.0, 59686.0, 87110.5, 235977.5, 90236.33333333333, 20471.0, 12492.0, 66446.0, 19470.333333333332], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
groupbyCity = _20191.groupby('City1')['Distance_GC_(km)'].max()
px.line(data_frame=groupbyCity,x=groupbyCity.index,y=groupbyCity.values)
# Out:
# <div>
#
#
#             <div id="9974f4b1-907c-4375-be8c-51a93b9ec5c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9974f4b1-907c-4375-be8c-51a93b9ec5c4")) {
#                     Plotly.newPlot(
#                         '9974f4b1-907c-4375-be8c-51a93b9ec5c4',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": ["ADELAIDE", "ALBURY", "ALICE SPRINGS", "ARMIDALE", "AYERS ROCK", "BALLINA", "BRISBANE", "BROOME", "BUNDABERG", "CAIRNS", "CANBERRA", "COFFS HARBOUR", "DARWIN", "DUBBO", "GERALDTON", "GOLD COAST", "HAMILTON ISLAND", "HOBART", "KALGOORLIE", "KARRATHA", "LAUNCESTON", "MELBOURNE", "PERTH", "PORT MACQUARIE", "PROSERPINE", "SUNSHINE COAST", "SYDNEY"], "xaxis": "x", "y": [2120, 452, 2022, 382, 2181, 612, 3615, 1677, 287, 2311, 470, 443, 3155, 310, 370, 680, 1526, 1039, 538, 1250, 914, 2706, 3284, 321, 1517, 1454, 1690], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
year_passenger_trip = df.groupby('Year')['Passenger_Trips'].mean()
px.line(data_frame=year_passenger_trip,x=year_passenger_trip.index,y=year_passenger_trip.values,)
# Out:
# <div>
#
#
#             <div id="b2e6662e-d232-439d-aeaf-a17951ade0b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2e6662e-d232-439d-aeaf-a17951ade0b0")) {
#                     Plotly.newPlot(
#                         'b2e6662e-d232-439d-aeaf-a17951ade0b0',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [18238.44881889764, 19128.7969348659, 20178.901328273245, 21232.174721189593, 24340.165714285715, 19594.746963562753, 23913.84117647059, 30447.44380952381, 32214.94230769231, 36079.29150579151, 37876.494755244756, 36696.137071651094, 39084.56329113924, 38935.72884012539, 39221.163265306124, 40481.119122257056, 44176.76898734177, 44875.56514913658, 41500.42290076336, 45150.55656108597, 51818.06363636364, 55231.60091743119, 57561.75454545455, 60680.448484848486, 62140.481962481965, 60699.45856353591, 64193.10176390773, 62553.94966887417, 63563.60127388535, 63147.01102941176, 65264.38819095477, 65089.078260869566, 66070.51225490196, 66136.89830508475, 66054.81309523809, 65009.223809523806], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
year_passenger_load_factor = df.groupby('Year')['Passenger_Load_Factor'].mean()
px.line(x=year_passenger_load_factor.index,y=year_passenger_load_factor.values)
# Out:
# <div>
#
#
#             <div id="9358f767-86df-4b15-92fc-111c9bc9fa4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9358f767-86df-4b15-92fc-111c9bc9fa4f")) {
#                     Plotly.newPlot(
#                         '9358f767-86df-4b15-92fc-111c9bc9fa4f',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [70.55275590551183, 70.57452107279697, 70.846110056926, 71.88736059479554, 75.19047619047618, 71.47631578947365, 69.57529411764706, 71.27580952380947, 73.3784615384616, 74.61370656370659, 72.76925222646857, 69.64980199579438, 69.18509280424061, 69.32137604377743, 69.90021529679751, 71.1628395348276, 71.4288973779747, 72.01445650425434, 70.97114582422896, 72.85254011509802, 73.42246178036365, 71.63715596330283, 68.12803030303034, 67.45833333333336, 65.64141414141415, 67.56146408839786, 67.87924016282224, 66.21695364238411, 65.14636942675156, 65.29791666666671, 68.66834170854275, 69.22372670807452, 70.03946078431376, 70.55278450363201, 70.72988095238087, 68.86507936507932], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
df.head()
# Out:
#       City1          City2  Month  Passenger_Trips  Aircraft_Trips  \
# 0  ADELAIDE  ALICE SPRINGS  30682            15743             143
# 1  ADELAIDE       BRISBANE  30682             3781              32
# 2  ADELAIDE       CANBERRA  30682             1339              12
# 3  ADELAIDE         DARWIN  30682             3050              33
# 4  ADELAIDE     GOLD COAST  30682             1596              16
#
#    Passenger_Load_Factor  Distance_GC_(km)      RPKs      ASKs  Seats  Year  \
# 0                   81.8              1316  20717788  25327369  19246  1984
# 1                   89.8              1622   6132782   6829379   4210  1984
# 2                   94.7               972   1301508   1374348   1414  1984
# 3                   66.8              2619   7987950  11958009   4566  1984
# 4                   88.5              1607   2564772   2898047   1803  1984
#
#    Month_num
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
distance_year_min = df.groupby('Year')['Distance_GC_(km)'].mean().sort_values()

# %%
px.bar(x=distance_year_min.index,y=distance_year.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-52e977462bf5> in <module>
# ----> 1 px.bar(x=distance_year_min.index,y=distance_year.values)
#
# NameError: name 'distance_year' is not defined

# %%
_2019Seats = df[df['Year']==2019].groupby('Month_num')['Seats'].mean()
px.line(x=_2019Seats.index,y=_2019Seats.values)
# Out:
# <div>
#
#
#             <div id="f8f008e0-276f-47ac-aad5-0e30a1f05fe5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f8f008e0-276f-47ac-aad5-0e30a1f05fe5")) {
#                     Plotly.newPlot(
#                         'f8f008e0-276f-47ac-aad5-0e30a1f05fe5',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "xaxis": "x", "y": [83617.18571428572, 74609.91428571429, 82699.25714285714, 83535.52857142857, 81747.81428571428, 78268.37142857142, 86832.5142857143, 81703.22857142857, 82155.64285714286], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
average_distance_mean = df.groupby('Year')['Distance_GC_(km)'].mean()
px.line(average_distance_mean.index,average_distance_mean.values)
# Out:
# <div>
#
#
#             <div id="ca60eb59-9534-4999-9832-2b607a4ccc22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca60eb59-9534-4999-9832-2b607a4ccc22")) {
#                     Plotly.newPlot(
#                         'ca60eb59-9534-4999-9832-2b607a4ccc22',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1222.8996062992126, 1242.0862068965516, 1246.4402277039849, 1275.2546468401488, 1256.3695238095238, 1221.1214574898786, 1202.821568627451, 1237.1580952380953, 1237.0346153846153, 1241.2277992277993, 1223.7342657342658, 1217.9096573208724, 1215.3101265822784, 1198.4043887147336, 1194.3186813186812, 1202.0297805642633, 1188.117088607595, 1207.6028257456828, 1228.8992366412215, 1234.2941176470588, 1228.6545454545455, 1211.3654434250764, 1210.680303030303, 1210.6727272727273, 1189.4444444444443, 1207.5635359116022, 1227.8710990502036, 1223.9072847682119, 1201.6955414012739, 1198.1299019607843, 1220.070351758794, 1218.9192546583852, 1212.514705882353, 1190.8898305084747, 1189.6857142857143, 1188.5111111111112], "xaxis": "x", "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...
